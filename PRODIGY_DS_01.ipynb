# %% [markdown]
# **Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
df = pd.read_csv('/content/Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_6508519.csv')

# We have categorical variable which name is IncomeGroup

# Select income group and country information
income_df = df[['Country Code', 'IncomeGroup']]

# Drop rows with missing value
income_df = income_df.dropna(subset=['IncomeGroup'])

# Count the number of countries in each income group
income_counts = income_df['IncomeGroup'].value_counts()

# Plot a bar chart
plt.figure(figsize=(10, 6))
income_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Income Group')
plt.ylabel('Number of Countries')
plt.title('Distribution of Countries by Income Group')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Check the Size of the income dataframe**

# %%
income_df.shape
# Out:
# (216, 2)

# %% [markdown]
# **Print the First 10 Records of income dataframe**

# %%
income_df.head(10)
# Out:
#    Country Code          IncomeGroup
# 0           ABW          High income
# 2           AFG           Low income
# 4           AGO  Lower middle income
# 5           ALB  Upper middle income
# 6           AND          High income
# 8           ARE          High income
# 9           ARG  Upper middle income
# 10          ARM  Upper middle income
# 11          ASM          High income
# 12          ATG          High income

# %% [markdown]
# **Print the last 10 records of income dataframe**

# %%
income_df.tail(10)
# Out:
#     Country Code          IncomeGroup
# 254          VGB          High income
# 255          VIR          High income
# 256          VNM  Lower middle income
# 257          VUT  Lower middle income
# 259          WSM  Lower middle income
# 260          XKX  Upper middle income
# 261          YEM           Low income
# 262          ZAF  Upper middle income
# 263          ZMB  Lower middle income
# 264          ZWE  Lower middle income

# %% [markdown]
# **Details of income dataframe**

# %%
income_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 216 entries, 0 to 264
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  216 non-null    object
#  1   IncomeGroup   216 non-null    object
# dtypes: object(2)
# memory usage: 5.1+ KB

# %%
income_df.describe()
# Out:
#        Country Code  IncomeGroup
# count           216          216
# unique          216            4
# top             ABW  High income
# freq              1           82

# %% [markdown]
# **Check the null values of dataframe**

# %%
income_df.isnull()
# Out:
#      Country Code  IncomeGroup
# 0           False        False
# 2           False        False
# 4           False        False
# 5           False        False
# 6           False        False
# ..            ...          ...
# 260         False        False
# 261         False        False
# 262         False        False
# 263         False        False
# 264         False        False
#
# [216 rows x 2 columns]

# %%
income_df.isnull().sum()
# Out:
# Country Code    0
# IncomeGroup     0
# dtype: int64
